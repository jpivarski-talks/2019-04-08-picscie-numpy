# %% [markdown]
# <br><br><br><br><br>
#
# # Day 2 Homework
#
# <br><br><br><br><br>

# %%
import PIL.Image
import numpy

def show(data):
    image = numpy.empty(data.shape + (3,))
    image[:, :, :] = data.reshape(data.shape + (1,))
    image -= image.min()
    image *= 255 / image.max()
    return PIL.Image.fromarray(image.astype(numpy.uint8))

# %%
y = numpy.array(PIL.Image.open("img/galaxy-infrared.jpg")).mean(axis=2)
height, width = y.shape
X = numpy.dstack(numpy.mgrid[0:height, 0:width]).reshape(height * width, 2)
show(y)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x600 at 0x7FD6A4090C88>

# %%
import sklearn.tree
model = sklearn.tree.DecisionTreeRegressor(max_depth=18)
model.fit(X, y.reshape(height * width, 1))
show(model.predict(X).reshape(height, width))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x600 at 0x7FD6C457E5C0>
